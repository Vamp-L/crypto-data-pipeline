# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../data/Bronze/crypto_prices.csv")

# %%
df(["mame"], ["market_cap"], ["price"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df(["mame"], ["market_cap"], ["price"])
#
# TypeError: 'DataFrame' object is not callable
