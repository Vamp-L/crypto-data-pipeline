# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../data/Bronze/github_raw.csv")

# %%
df.head(10)
# Out:
#            id                           node_id                         name  \
# 0   132750724  MDEwOlJlcG9zaXRvcnkxMzI3NTA3MjQ=             build-your-own-x
# 1    21737465  MDEwOlJlcG9zaXRvcnkyMTczNzQ2NQ==                      awesome
# 2    28457823  MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==                 freeCodeCamp
# 3    54346799  MDEwOlJlcG9zaXRvcnk1NDM0Njc5OQ==                  public-apis
# 4    13491895  MDEwOlJlcG9zaXRvcnkxMzQ5MTg5NQ==       free-programming-books
# 5    85077558  MDEwOlJlcG9zaXRvcnk4NTA3NzU1OA==            developer-roadmap
# 6    83222441  MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==         system-design-primer
# 7    60493101  MDEwOlJlcG9zaXRvcnk2MDQ5MzEwMQ==  coding-interview-university
# 8  1103012935                      R_kgDOQb6kRw                     openclaw
# 9    21289110  MDEwOlJlcG9zaXRvcnkyMTI4OTExMA==               awesome-python
#
#                                 full_name  private  \
# 0        codecrafters-io/build-your-own-x    False
# ...

# %%
df = df.fillna(0)

# %%
df = df.drop_duplicates()
os.makedirs("../data/Silver", exist_ok=True)
df.to_csv("../data/Silver/github_clean.csv", index=False)
print("Silver Data Saved")
# Out:
# Silver Data Saved
